# %%
germenes_nosocomiales = [
    {
        "germen": "Staphylococcus aureus resistente a meticilina (MRSA)",
        "lugares_de_accion": {
            "piel_y_tejidos_blandos": 30,
            "neumonia": 20,
            "bacteriemia": 10
        }
    },
    {
        "germen": "Enterococcus resistente a vancomicina (VRE)",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 25,
            "bacteriemia": 15,
            "infecciones_de_heridas": 10
        }
    },
    {
        "germen": "Clostridioides difficile (C. difficile)",
        "lugares_de_accion": {
            "colitis_pseudomembranosa": 60,
            "diarrea_asociada_a_antibioticos": 40
        }
    },
    {
        "germen": "Pseudomonas aeruginosa",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 20,
            "neumonia": 25,
            "infecciones_de_heridas_y_quemaduras": 15
        }
    },
    {
        "germen": "Acinetobacter baumannii",
        "lugares_de_accion": {
            "neumonia": 30,
            "infecciones_de_heridas": 25,
            "bacteriemia": 10
        }
    },
    {
        "germen": "Klebsiella pneumoniae",
        "lugares_de_accion": {
            "neumonia": 30,
            "infecciones_del_trato_urinario": 20,
            "bacteriemia": 10
        }
    },
    {
        "germen": "Escherichia coli (productor de BLEE)",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 35,
            "bacteriemia": 20,
            "infecciones_intraabdominales": 10
        }
    },
    {
        "germen": "Enterobacter spp.",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 20,
            "infecciones_intraabdominales": 15,
            "bacteriemia": 10
        }
    },
    {
        "germen": "Candida spp.",
        "lugares_de_accion": {
            "candidiasis_invasiva": 25,
            "infecciones_del_torrente_sanguineo": 20,
            "infecciones_del_trato_urinario": 15
        }
    },
    {
        "germen": "Serratia marcescens",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 15,
            "neumonia": 20,
            "bacteriemia": 10
        }
    }
]

# Ejemplo de cómo acceder a los datos
for germen in germenes_nosocomiales:
    print(f"Germen: {germen['germen']}")
    for lugar, porcentaje in germen['lugares_de_accion'].items():
        print(f"  {lugar.replace('_', ' ').title()}: {porcentaje}%")
# Out:
# Germen: Staphylococcus aureus resistente a meticilina (MRSA)
#   Piel Y Tejidos Blandos: 30%
#   Neumonia: 20%
#   Bacteriemia: 10%
# Germen: Enterococcus resistente a vancomicina (VRE)
#   Infecciones Del Trato Urinario: 25%
#   Bacteriemia: 15%
#   Infecciones De Heridas: 10%
# Germen: Clostridioides difficile (C. difficile)
#   Colitis Pseudomembranosa: 60%
#   Diarrea Asociada A Antibioticos: 40%
# Germen: Pseudomonas aeruginosa
#   Infecciones Del Trato Urinario: 20%
#   Neumonia: 25%
#   Infecciones De Heridas Y Quemaduras: 15%
# Germen: Acinetobacter baumannii
#   Neumonia: 30%
#   Infecciones De Heridas: 25%
#   Bacteriemia: 10%
# Germen: Klebsiella pneumoniae
#   Neumonia: 30%
#   Infecciones Del Trato Urinario: 20%
#   Bacteriemia: 10%
# Germen: Escherichia coli (productor de BLEE)
#   Infecciones Del Trato Urinario: 35%
#   Bacteriemia: 20%
#   Infecciones Intraabdominales: 10%
# Germen: Enterobacter spp.
#   Infecciones Del Trato Urinario: 20%
# ...

# %%
germenes_nosocomiales = [
    {
        "germen": "Staphylococcus aureus resistente a meticilina (MRSA)",
        "lugares_de_accion": {
            "piel_y_tejidos_blandos": 30,
            "neumonia": 20,
            "bacteriemia": 10
        },
        "antibioticos": [
            "Vancomicina",
            "Linezolid",
            "Daptomicina",
            "Ceftarolina"
        ]
    },
    {
        "germen": "Enterococcus resistente a vancomicina (VRE)",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 25,
            "bacteriemia": 15,
            "infecciones_de_heridas": 10
        },
        "antibioticos": [
            "Linezolid",
            "Daptomicina",
            "Tigeciclina"
        ]
    },
    {
        "germen": "Clostridioides difficile (C. difficile)",
        "lugares_de_accion": {
            "colitis_pseudomembranosa": 60,
            "diarrea_asociada_a_antibioticos": 40
        },
        "antibioticos": [
            "Metronidazol",
            "Vancomicina oral",
            "Fidaxomicina"
        ]
    },
    {
        "germen": "Pseudomonas aeruginosa",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 20,
            "neumonia": 25,
            "infecciones_de_heridas_y_quemaduras": 15
        },
        "antibioticos": [
            "Piperacilina/Tazobactam",
            "Ceftazidima",
            "Cefepima",
            "Meropenem",
            "Imipenem",
            "Colistina"
        ]
    },
    {
        "germen": "Acinetobacter baumannii",
        "lugares_de_accion": {
            "neumonia": 30,
            "infecciones_de_heridas": 25,
            "bacteriemia": 10
        },
        "antibioticos": [
            "Meropenem",
            "Imipenem",
            "Colistina",
            "Tigeciclina"
        ]
    },
    {
        "germen": "Klebsiella pneumoniae",
        "lugares_de_accion": {
            "neumonia": 30,
            "infecciones_del_trato_urinario": 20,
            "bacteriemia": 10
        },
        "antibioticos": [
            "Meropenem",
            "Imipenem",
            "Tigeciclina",
            "Colistina"
        ]
    },
    {
        "germen": "Escherichia coli (productor de BLEE)",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 35,
            "bacteriemia": 20,
            "infecciones_intraabdominales": 10
        },
        "antibioticos": [
            "Meropenem",
            "Imipenem",
            "Ertapenem"
        ]
    },
    {
        "germen": "Enterobacter spp.",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 20,
            "infecciones_intraabdominales": 15,
            "bacteriemia": 10
        },
        "antibioticos": [
            "Meropenem",
            "Imipenem",
            "Cefepima"
        ]
    },
    {
        "germen": "Candida spp.",
        "lugares_de_accion": {
            "candidiasis_invasiva": 25,
            "infecciones_del_torrente_sanguineo": 20,
            "infecciones_del_trato_urinario": 15
        },
        "antibioticos": [
            "Fluconazol",
            "Anfotericina B",
            "Caspofungina",
            "Micafungina"
        ]
    },
    {
        "germen": "Serratia marcescens",
        "lugares_de_accion": {
            "infecciones_del_trato_urinario": 15,
            "neumonia": 20,
            "bacteriemia": 10
        },
        "antibioticos": [
            "Cefepima",
            "Meropenem",
            "Imipenem"
        ]
    }
]

# Ejemplo de cómo acceder a los datos
for germen in germenes_nosocomiales:
    print(f"Germen: {germen['germen']}")
    for lugar, porcentaje in germen['lugares_de_accion'].items():
        print(f"  {lugar.replace('_', ' ').title()}: {porcentaje}%")
    print("  Antibióticos: " + ", ".join(germen['antibioticos']))
# Out:
# Germen: Staphylococcus aureus resistente a meticilina (MRSA)
#   Piel Y Tejidos Blandos: 30%
#   Neumonia: 20%
#   Bacteriemia: 10%
#   Antibióticos: Vancomicina, Linezolid, Daptomicina, Ceftarolina
# Germen: Enterococcus resistente a vancomicina (VRE)
#   Infecciones Del Trato Urinario: 25%
#   Bacteriemia: 15%
#   Infecciones De Heridas: 10%
#   Antibióticos: Linezolid, Daptomicina, Tigeciclina
# Germen: Clostridioides difficile (C. difficile)
#   Colitis Pseudomembranosa: 60%
#   Diarrea Asociada A Antibioticos: 40%
#   Antibióticos: Metronidazol, Vancomicina oral, Fidaxomicina
# Germen: Pseudomonas aeruginosa
#   Infecciones Del Trato Urinario: 20%
#   Neumonia: 25%
#   Infecciones De Heridas Y Quemaduras: 15%
#   Antibióticos: Piperacilina/Tazobactam, Ceftazidima, Cefepima, Meropenem, Imipenem, Colistina
# Germen: Acinetobacter baumannii
#   Neumonia: 30%
#   Infecciones De Heridas: 25%
#   Bacteriemia: 10%
#   Antibióticos: Meropenem, Imipenem, Colistina, Tigeciclina
# ...
